# %% [markdown]
# ## This is a  diamond data, i will be using scaling method on diamond data.
# Imorting packages

# %%
import pandas as pd
import sklearn.preprocessing as prepro

# %%
#Read csv file into data frame
df= pd.read_csv('diamonds.csv')

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ### Note: Never scale anything that is norminal.
# Norminal datas are numerical data's that are just labels and are mutually exclusive to each other. They are mostly used to categorise or identify something, example 'year 2016' is a norminal data tho numerical, we cant scale it. If we do it looses it meaning because minmax scalling for example brings all values to 1 and 0.

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %% [markdown]
# ## in other to determine which variable to scale in a dataset, we must consider the following:
# 1.Is it a numerical/ not.
# 2. Is it norminal/not
# 3. Check the range of the data (min and max). If the min and max are largely diffrent eg. min is in unit value and max is in thousand, you should scale.
# ## To determine what method of scalling to used, condiser the following:
# 1.Is the data skewed, if yes (minmax scakler)
# 2.Is the data gaussian, if yes(Stardardization scalling)
# 3.Is the data sparse, if yes (L2 normalisation). Spares data are datas that have a lot of zeros in it.
#
# ###### looking at diamond, we can see that the range of {carrat, depth and table are close i.e they in the same range Ten's. But the price column hasa sig diiffrent range ie min is in 100's and max is in 1000's }

# %% [markdown]
# ### Plot

# %%
import seaborn as sns

# %%
sns.histplot(data=df, x="price")
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# As seen from the plot, the price column is skewed, so we used MinMax scaler
# ### Scaling price column

# %%
df["price_scaled"]= prepro.minmax_scale(df[["price"]])

# %% [markdown]
# ### Disclaimer: CodeMentor explainer
# "The function being used here is prepro.minmax_scale(), which is a part of the minmax_scale module in the prepro library. This function is used to scale the values of a given feature or column to a specified range, typically between 0 and 1.
#
# In this case, the "price" column is being selected from the DataFrame using double square brackets df[["price"]]. The double square brackets are used to select a single column as a DataFrame, rather than a Series.
#
# The minmax_scale() function takes this selected column as an input and returns the scaled values. The scaled values are then assigned to a new column called "price_scaled" in the original DataFrame using the assignment operator =.
#
# This line of code is useful when working with numerical data that has a wide range of values. Scaling the values to a specific range can help in improving the performance of certain machine learning algorithms, as it ensures that all features are on a similar scale."

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    price_scaled
# 0      0.000000
# 1      0.000000
# 2      0.000054
# 3      0.000433
# 4      0.000487

# %%
sns.histplot(data=df, x="price_scaled")
# Out:
# <Axes: xlabel='price_scaled', ylabel='Count'>

# %% [markdown]
# As show above the price column as been scaled but even at that the shape/ pattern/ distribution in the price column remain unultred, this is because the goal of scalling is not to alter the pattern but to bring it into data between 0 and 1

# %%
sns.pairplot(df)

# %% [markdown]
# If we look at the pair plot above, we can see that depth column kindof have a gaussian distribution. To confirm thus we can histplot it's distribution.

# %%
import matplotlib.pyplot as plt

# %%
sns.histplot(data=df, x= "depth")
plt.title("depth column distribution")
# Out:
# Text(0.5, 1.0, 'depth column distribution')

# %% [markdown]
# Haven confirmed it is certaily a normally distributed data, we can use the 'standard scaler' to scale it.

# %%
df['depth_scaled']= prepro.StandardScaler().fit_transform(df[["depth"]])
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    price_scaled  depth_scaled
# 0      0.000000     -0.174092
# 1      0.000000     -1.360738
# 2      0.000054     -3.385019
# 3      0.000433      0.454133
# 4      0.000487      1.082358

# %% [markdown]
# ***prepro.StandardScaler().fit_transform(df[["depth"]])***
#
#
# "This line of code is used to create a new column in a dataframe called 'depth_scaled'. The values in this new column will be the scaled values of the 'depth' column in the dataframe.
#
# The 'prepro.StandardScaler()' part of the code is creating an instance of the StandardScaler class from the preprocessing module in the scikit-learn library. The StandardScaler class is used to standardize features by removing the mean and scaling to unit variance.
#
# The 'fit_transform()' method is then called on the StandardScaler instance. This method fits the scaler to the 'depth' column data and then transforms the data by applying the scaling. The 'fit_transform()' method returns the transformed data, which is then assigned to the 'depth_scaled' column in the dataframe.
#
# The 'df[["depth"]]' part of the code is selecting the 'depth' column from the dataframe and passing it as input to the scaler's 'fit_transform()' method. The double square brackets are used to create a dataframe with a single column, as the 'fit_transform()' method expects a 2D array-like input.
#
# Overall, this line of code is performing feature scaling on the 'depth' column in the dataframe and storing the scaled values in a new column called 'depth_scaled'." (code-mentor.ai)

# %% [markdown]
# ## Histo_plot depth

# %%
sns.histplot(data=df, x='depth_scaled')
# Out:
# <Axes: xlabel='depth_scaled', ylabel='Count'>

# %% [markdown]
# As shown above, the pattern is unultered but the depth has been scaled using the standardise scale method. It is worth noting that the standardised scaler scales the data by removing the mean, and

# %% [markdown]
# ## Note on scaling
# 1. scaling should be done after cleaning
# 2. Don't scale norminal data
# 3. Dont scale dependent variable, if we do ML will predict scaled value not actual values.
# 4. Use Normalisation for gaussian distribution, MinMax for skwed data, Normalizatio L2 for spared data.

# %% [markdown]
# ## How to unscale data

# %%
from sklearn.preprocessing import StandardScaler # This line of code imports starndard scaler algarithm from the preprocessing
# Laibrary in sklearn.

# %%
sc= StandardScaler() #StandardScaler is stored in the variable 'sc'

# %%
df['depth_scaled']= sc.fit_transform(df[["depth"]]) # 
# "using sc, fit transform depth column from df to standard scale, and store operation in variable 'df['depth_scaled']'.'

# %%
#df['depth_scaled']= prepro.StandardScaler().fit_transform(df[["depth"]])
df['unscale_depth']=sc.inverse_transform(df[['depth_scaled']])
df.head()
# Using the invers transform method, unscale the 'df['depth_scaled'] you scaled intitially, and store Unsclaed 
# column in new variable "df['unscale_depth']".
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    price_scaled  depth_scaled  unscale_depth
# 0      0.000000     -0.174092           61.5
# 1      0.000000     -1.360738           59.8
# 2      0.000054     -3.385019           56.9
# 3      0.000433      0.454133           62.4
# 4      0.000487      1.082358           63.3

# %% [markdown]
# Scaled vs un_scaled values of depth
# ![Screenshot%202023-11-08%20233608.png](attachment:Screenshot%202023-11-08%20233608.png)

# %%
pip install RISE
# Out:
# Collecting RISE
#   Downloading rise-5.7.1-py2.py3-none-any.whl (4.3 MB)
#      ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#      -- ------------------------------------- 0.2/4.3 MB 5.0 MB/s eta 0:00:01
#      ------- -------------------------------- 0.8/4.3 MB 8.5 MB/s eta 0:00:01
#      -------------------- ------------------- 2.2/4.3 MB 15.2 MB/s eta 0:00:01
#      ---------------------------- ----------- 3.1/4.3 MB 16.4 MB/s eta 0:00:01
#      ---------------------------------------  4.3/4.3 MB 19.5 MB/s eta 0:00:01
#      ---------------------------------------- 4.3/4.3 MB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: notebook>=6.0 in c:\users\timay\anaconda3\lib\site-packages (from RISE) (6.5.4)
# Requirement already satisfied: jinja2 in c:\users\timay\anaconda3\lib\site-packages (from notebook>=6.0->RISE) (3.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\timay\anaconda3\lib\site-packages (from notebook>=6.0->RISE) (6.3.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\timay\anaconda3\lib\site-packages (from notebook>=6.0->RISE) (23.2.0)
# Requirement already satisfied: argon2-cffi in c:\users\timay\anaconda3\lib\site-packages (from notebook>=6.0->RISE) (21.3.0)
# Requirement already satisfied: traitlets>=4.2.1 in c:\users\timay\anaconda3\lib\site-packages (from notebook>=6.0->RISE) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\timay\anaconda3\lib\site-packages (from notebook>=6.0->RISE) (5.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\timay\anaconda3\lib\site-packages (from notebook>=6.0->RISE) (7.4.9)
# Requirement already satisfied: ipython-genutils in c:\users\timay\anaconda3\lib\site-packages (from notebook>=6.0->RISE) (0.2.0)
# Requirement already satisfied: nbformat in c:\users\timay\anaconda3\lib\site-packages (from notebook>=6.0->RISE) (5.7.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\timay\anaconda3\lib\site-packages (from notebook>=6.0->RISE) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\timay\anaconda3\lib\site-packages (from notebook>=6.0->RISE) (1.5.6)
# Requirement already satisfied: ipykernel in c:\users\timay\anaconda3\lib\site-packages (from notebook>=6.0->RISE) (6.19.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\timay\anaconda3\lib\site-packages (from notebook>=6.0->RISE) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\timay\anaconda3\lib\site-packages (from notebook>=6.0->RISE) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\timay\anaconda3\lib\site-packages (from notebook>=6.0->RISE) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\timay\anaconda3\lib\site-packages (from notebook>=6.0->RISE) (0.5.5)
# Requirement already satisfied: entrypoints in c:\users\timay\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=6.0->RISE) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\timay\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=6.0->RISE) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\timay\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook>=6.0->RISE) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\timay\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook>=6.0->RISE) (305.1)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\timay\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=6.0->RISE) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\timay\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=6.0->RISE) (0.2.2)
# Requirement already satisfied: lxml in c:\users\timay\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=6.0->RISE) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\timay\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=6.0->RISE) (4.12.2)
# Requirement already satisfied: bleach in c:\users\timay\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=6.0->RISE) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\timay\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=6.0->RISE) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\timay\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=6.0->RISE) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\timay\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=6.0->RISE) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\timay\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=6.0->RISE) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\timay\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=6.0->RISE) (0.5.13)
# Requirement already satisfied: packaging in c:\users\timay\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=6.0->RISE) (23.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\timay\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=6.0->RISE) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\timay\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=6.0->RISE) (2.15.1)
# Requirement already satisfied: tinycss2 in c:\users\timay\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=6.0->RISE) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\timay\anaconda3\lib\site-packages (from nbformat->notebook>=6.0->RISE) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\timay\anaconda3\lib\site-packages (from nbformat->notebook>=6.0->RISE) (4.17.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\timay\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=6.0->RISE) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\timay\anaconda3\lib\site-packages (from argon2-cffi->notebook>=6.0->RISE) (21.2.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\timay\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->RISE) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\timay\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->RISE) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\timay\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->RISE) (8.12.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\timay\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->RISE) (0.1.6)
# Requirement already satisfied: psutil in c:\users\timay\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->RISE) (5.9.0)
# Requirement already satisfied: backcall in c:\users\timay\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->RISE) (0.2.0)
# Requirement already satisfied: decorator in c:\users\timay\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->RISE) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\timay\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->RISE) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\timay\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->RISE) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\timay\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->RISE) (3.0.36)
# Requirement already satisfied: stack-data in c:\users\timay\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->RISE) (0.2.0)
# Requirement already satisfied: colorama in c:\users\timay\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->RISE) (0.4.6)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\timay\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=6.0->RISE) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\timay\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=6.0->RISE) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\timay\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->RISE) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\timay\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->RISE) (0.58.0)
# Requirement already satisfied: six>=1.5 in c:\users\timay\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=5.3.4->notebook>=6.0->RISE) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\timay\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.0->RISE) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\timay\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=6.0->RISE) (2.4)
# Requirement already satisfied: webencodings in c:\users\timay\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=6.0->RISE) (0.5.1)
# Requirement already satisfied: idna>=2.8 in c:\users\timay\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->RISE) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\timay\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->RISE) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\timay\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.0->RISE) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\timay\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook>=6.0->RISE) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\timay\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->notebook>=6.0->RISE) (0.2.5)
# Requirement already satisfied: executing in c:\users\timay\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.0->RISE) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\timay\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.0->RISE) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\timay\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.0->RISE) (0.2.2)
# Installing collected packages: RISE
# Successfully installed RISE-5.7.1
# Note: you may need to restart the kernel to use updated packages.
